# %% [markdown]
# ![Screenshot%202022-12-20%20at%2010.20.05%20PM.png](attachment:Screenshot%202022-12-20%20at%2010.20.05%20PM.png)

# %%
import numpy as np

# %%
ls
# Out:
# Screenshot 2022-12-20 at 10.20.05 PM.png
# Untitled.ipynb
# price_temp.txt
# rate_temp.txt

# %%
price_temp = np.loadtxt("price_temp.txt")

rate_temp = np.loadtxt("rate_temp.txt",skiprows=1)

print("price_temp sample : " , price_temp[0][:10]) # just sample
print()
print("rate_temp sample : " ,rate_temp[:10])  # just sample
# Out:
# price_temp sample :  [74.69 15.28 46.33 58.22 86.31 85.39 68.84 73.56 36.26 54.84]
#
# rate_temp sample :  [9.1 9.6 7.4 8.4 5.3 4.1 5.8 8.  7.2 5.9]

# %% [markdown]
# <h3> statistical functions to price_temp  </h3>

# %%
price_temp.max()
# Out:
# 939.54

# %%
price_temp.min()
# Out:
# 0.7715

# %%
price_temp.mean()
# Out:
# 147.53632333333334

# %%
price_temp.sum()
# Out:
# 44260.897000000004

# %%
price_temp.var()
# Out:
# 45440.385805160455

# %%
price_temp.std()
# Out:
# 213.1675064477709

# %%
price_temp.shape
# Out:
# (3, 100)

# %% [markdown]
# <h3> statistical functions to rate_temp  </h3>

# %%
rate_temp.max()
# Out:
# 10.0

# %%
rate_temp.min()
# Out:
# 4.0

# %%
rate_temp.mean()
# Out:
# 6.893000000000001

# %%
rate_temp.sum()
# Out:
# 689.3000000000001

# %%
rate_temp.var()
# Out:
# 2.8202510000000007

# %%
rate_temp.std()
# Out:
# 1.6793602948742121

# %%
rate_temp.shape
# Out:
# (100,)

# %%
rate_temp
# Out:
# array([ 9.1,  9.6,  7.4,  8.4,  5.3,  4.1,  5.8,  8. ,  7.2,  5.9,  4.5,
#         6.8,  7.1,  8.2,  5.7,  4.5,  4.6,  6.9,  8.6,  4.4,  4.8,  5.1,
#         4.4,  9.9,  6. ,  8.5,  6.7,  7.7,  9.6,  7.4,  4.8,  4.5,  5.1,
#         5.1,  7.5,  6.8,  7. ,  4.7,  7.6,  7.7,  7.9,  6.3,  5.6,  7.6,
#         7.2,  9.5,  8.4,  4.1,  8.1,  7.9,  9.5,  8.5,  6.5,  6.1,  6.5,
#         8.2,  5.8,  6.6,  5.4,  9.3, 10. ,  7. , 10. ,  8.6,  7.6,  5.8,
#         6.7,  9.9,  6.4,  4.3,  9.6,  5.9,  4. ,  8.7,  9.4,  5.4,  8.6,
#         5.7,  6.6,  6. ,  5.5,  6.4,  6.6,  8.3,  6.6,  4. ,  9.9,  7.3,
#         5.7,  6.1,  7.1,  8.2,  5.1,  8.6,  6.6,  7.2,  5.1,  4.1,  9.3,
#         7.4])
