# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class ClassA:
    
    _First_name = None # _ == Private varibal you can not see it using Instance you must use self
    Last_Name = None
    
    def __init__(self , First_name):
        self._First_name = First_name
        
    @classmethod
    def class_description(cls):
        return """
        this class just for learning 
        
        and this function you can Accessit Public without create instance to call it ... 
        """
    
    @property
    def name(self):
        return self._First_name
    
    @name.setter
    def name(self , value):
        self._First_name =  value

# %%
help(ClassA)
# Out:
# Help on class ClassA in module __main__:
#
# class ClassA(builtins.object)
#  |  ClassA(First_name)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, First_name)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  class_description() from builtins.type
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  name
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  Last_Name = None

# %%
print(ClassA.class_description())
# Out:
#         this class just for learning
#
#         and this function you can Accessit Public without create instance to call it ...

# %%
ClassA.name

# %%
ClassA_instance = ClassA("Abdulwahab")

# %%
ClassA_instance.

# %%
ClassA_instance.name
# Out:
# 'Abdulwahab'

# %%
import sys , os

# %%
os.listdir()
# Out:
# ['Untitled.ipynb', 'untitled.txt', '.ipynb_checkpoints']

# %%
# pip install ipykernel

# %%
ipykernel install --user
# Out:
#   Cell In[118], line 1
#     ipykernel install --user
#               ^
# SyntaxError: invalid syntax

# %%
ls
# Out:
# Untitled.ipynb  untitled.txt

# %%
import numpy as np

# %%
ls
# Out:
# Untitled.ipynb  untitled.txt

# %%
loadfile = np.loadtxt("untitled.txt",dtype='datetime64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 loadfile = np.load("untitled.txt",dtype='datetime64')
#
# TypeError: load() got an unexpected keyword argument 'dtype'

# %%
import pandas as pd

# %%
np.savetxt("untitled.txt",loadfile)

# %%
import datetime

# %%
dd = datetime.datetime.now()

# %%
type(datetime.datetime.now())
# Out:
# datetime.datetime

# %%
print(datetime.datetime.now())
# Out:
# 2022-12-20 12:13:48.363985
