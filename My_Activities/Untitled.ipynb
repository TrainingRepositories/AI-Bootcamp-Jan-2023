# %% [markdown]
# <h2> "this Page to install all NEXUS Libraries was installed in there lab" </h2>

# %%
ls ../Setup_requirements/DSI_001
# Out:
# Setup_requirements.txt

# %%
dd = open("../Setup_requirements/DSI_001/Setup_requirements.txt","r")

# %%
with open("../Setup_requirements/DSI_001/Setup_requirements.txt","r") as file:
    for library in file.readlines():
        print(library)
# Out:
# alabaster==0.7.12
#
# anaconda-client==1.7.2
#
# anaconda-navigator==1.9.12
#
# anaconda-project==0.8.3
#
# argh==0.26.2
#
# asn1crypto==1.3.0
#
# astroid==2.3.3
#
# astropy==4.0
#
# atomicwrites==1.3.0
#
# attrs==19.3.0
#
# autopep8==1.4.4
#
# Babel==2.8.0
#
# backcall==0.1.0
#
# backports.functools-lru-cache==1.6.1
#
# backports.shutil-get-terminal-size==1.0.0
#
# backports.tempfile==1.0
#
# backports.weakref==1.0.post1
#
# beautifulsoup4==4.8.2
#
# bitarray==1.2.1
#
# bkcharts==0.2
#
# bleach==3.1.0
#
# bokeh==1.4.0
#
# boto==2.49.0
#
# Bottleneck==1.3.2
#
# certifi==2019.11.28
#
# cffi==1.14.0
#
# chardet==3.0.4
#
# Click==7.0
#
# cloudpickle==1.3.0
#
# clyent==1.2.2
#
# colorama==0.4.3
#
# conda==4.8.2
#
# conda-build==3.18.11
#
# conda-package-handling==1.6.0
#
# conda-verify==3.4.2
#
# contextlib2==0.6.0.post1
#
# cryptography==2.8
#
# cycler==0.10.0
#
# Cython==0.29.15
#
# cytoolz==0.10.1
#
# dask==2.11.0
#
# decorator==4.4.1
#
# defusedxml==0.6.0
#
# ...

# %%
pip install numpy==1.18.1
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 3.2 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.8962422867133006

# %%
import sys
sys.executable
# Out:
# '/usr/local/opt/python@3.7/bin/python3.7'

# %%
pip list
# Out:
# Package              Version
# -------------------- -----------
# anyio                3.6.2
# appnope              0.1.3
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# attrs                22.1.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               5.0.1
# cffi                 1.15.1
# debugpy              1.6.4
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# fastjsonschema       2.16.2
# idna                 3.4
# importlib-metadata   5.2.0
# importlib-resources  5.10.1
# ipykernel            6.16.2
# ipython              7.34.0
# ipython-genutils     0.2.0
# jedi                 0.18.2
# Jinja2               3.1.2
# jsonschema           4.17.3
# jupyter_client       7.4.8
# jupyter_core         4.12.0
# jupyter-server       1.23.4
# jupyterlab-pygments  0.2.2
# MarkupSafe           2.1.1
# matplotlib-inline    0.1.6
# mistune              2.0.4
# nbclassic            0.4.8
# ...
