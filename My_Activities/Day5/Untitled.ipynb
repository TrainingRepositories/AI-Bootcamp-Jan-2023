# %%
import matplotlib as mp
import seaborn as sb

# %%
import pandas as pd

# %%
ls ../../Matplotlib_data
# Out:
# daily_accounting_by_month.csv  stores_data_full_clean.csv
# daily_revenue_by_month.csv

# %%
fig , ax = mp.pyplot.subplots(nrows=1,ncols=2,figsize = (20, 10))

# %%
font_dict1 = {'fontsize': 20,'fontweight' : 5,'color':'red'}
font_dict2 = {'fontsize': 30,'fontweight' : 8,'color':'blue'}


ax[0].set_title("this is title for ax[0]",fontdict=font_dict)
ax[1].set_title("this is title for ax[1]",fontdict=font_dict2)
# Out:
# Text(0.5, 1, 'this is title for ax[1]')

# %%
fig

# %%
label1_font_dict = {'fontsize': 30,'fontweight' : 7,'color':'green'}
label2_font_dict = {'fontsize': 30,'fontweight' : 9,'color':'yellow'}

ax[0].set_xlabel("this is xlabel",fontdict=xlabel1_font_dict)
ax[0].set_ylabel("this is xlabel",fontdict=xlabel1_font_dict)


ax[1].set_xlabel("this is xlabel",fontdict=label2_font_dict)
ax[1].set_ylabel("this is xlabel",fontdict=label2_font_dict)
# Out:
# Text(611.9272727272726, 0.5, 'this is xlabel')

# %%
fig

# %%
daily_accounting_by_month = pd.read_csv("../../IntroToData/Matplotlib/data/daily_accounting_by_month.csv")
stores_data_full_clean = pd.read_csv("../../IntroToData/Matplotlib/data/stores_data_full_clean.csv")
daily_revenue_by_month = pd.read_csv("../../IntroToData/Matplotlib/data/daily_revenue_by_month.csv")

# %%
stores_data_full_clean.head()
# Out:
#      InvoiceID       Date        Branch CustomerType  Gender ProductLine  \
# 0  CAR-CLO-001  3/10/2019  Carbon Creek       Normal  Female    Clothing
# 1  CAR-CLO-002  1/12/2019  Carbon Creek       Member  Female    Clothing
# 2  CAR-CLO-003  2/10/2019  Carbon Creek       Member  Female    Clothing
# 3  CAR-CLO-004  1/29/2019  Carbon Creek       Normal    Male    Clothing
# 4  CAR-CLO-005   2/8/2019  Carbon Creek       Normal    Male    Clothing
#
#    UnitPrice  Quantity  TaxPrice  TotalPrice  Revenue    COGS  CustomerRating  \
# 0      87.67         2      8.77      184.11   175.34  170.12             7.7
# 1      20.01         9      9.00      189.09   180.09  174.55             5.7
# 2      30.14        10     15.07      316.47   301.40  284.76             9.2
# 3      83.24         9     37.46      786.62   749.16  709.60             7.4
# 4      98.98        10     49.49     1039.29   989.80  955.90             8.7
#
#    GrossIncome
# 0         5.22
# 1         5.54
# ...

# %%
test = ax[0]

# %%
test.scatter(x=stores_data_full_clean['TotalPrice'] , y=stores_data_full_clean['TaxPrice'])

# %%
fig
